# %%
#summary 

#list CHAPTER summary

#list is a data structur  that can hold any type of data 

#create a list 
words=['word1','word2']

#you can store anything inside list 
mixed =[1,2,3,[4,5,6],'seven',8.0,None]
print(mixed)
#list is ordered collection of items 
# print(mixed[2])
# print(mixed[3])

# add data to our list 
#append method

# mixed.append(10)
# print(mixed)

# mixed.append([10,20,30])
# print(mixed)

#extend method 
# mixed.extend([10,20,30])
# print(mixed)

#join two list 
# l=li+li 

#isert method 
# mixed.insert(1,'inserrted ')
# print(mixed)

#remove data from list
#pop method 
# popped=mixed.pop()
# print(popped)
# print(mixed)

# popped=mixed.pop(1)
# print(popped)

#remove method 
# mixed.remove('seven')
# print(mixed)

#del statement 
del mixed[3]
print (mixed)

#loop in list 
for i in mixed:
    print(i,end=" ")
