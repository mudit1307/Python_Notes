# %%
#6


# in keyword 

name="harshit"
if "a" in name:
    print('a is present in name ')
else:
    print('not present')
    

if "y" in "mudit":
    print('y is present in mudit')
else:
    print("y is not present in mudit")




# check empty or not 

name="abc"
if name:
    print('string is not empty')
else:
    print("string is empty")
    
name1=""
if name1 :
    print("string is not empty")
else:
    print("string is empty")


#example empty or not 
name=input("enter your name: ")
if name:
    print(f"your name is {name}")
else:
    print("you didn't type anything")

# %%
#7 

# while loop
i=1
while i<=5:
    print('hello world')
    i=i+1

i=1
while i<=10:
    print("hello world {} ".format(i))
    i=i+1 


# infinite loop in while   #terminate using -> ctrl +c
# i=1
# while i<=10:
#     print('hello world')

   


# sum of number program using while loop
total=0 
i=1
while i<=10:
    total = total+i
    i = i+1 
print(total)

# %%
#8 


# not in 

name="harshit vashistha"
if "h" not in name:
    print ("not present in name")
else:
    print('present in name')



#infinite loop 

# i=0 
# while i <10:
#     print ('hello world')


# while True:
#     print("hello world!!")

# %%
#9 

# for loop with range function 

for i in range(10):
    print('hello world:{}'.format(i))

for i in range(1,11):
    print('hello world:{}'.format(i))
    print('there is a line \n')

# %%
#10 

#for loop example 1
#sum from 1 to 10 
#1+2+3+4....+10

total = 0
for i in range(1,11):
    total+=i
print(total)



sum=0
num = int(input('enter a nuber here: '))
for j in range(1,num+1):
    sum+=j
print (sum)




#for loop example 2
total=0
number=input('enter a number here: ')

for i in range(len(number)):
    total+=int(number[i])
print(total)



#for loop example 3
name=input('enter your name: ')
temp_var=""
for i in range (len(name)):
    if name[i] not in temp_var:
        temp_var+=name[i]
        print(f"{name[i]} - {name.count(name[i])} ")
