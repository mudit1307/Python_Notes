# %%
#1 

'''EXERCISE 1 
NUMBER GUESSING GAME
'''
#QUESTION 
'''MAKE A VARIABLE, LIKE WINNING_NUMBER AND ASSIGN ANY NUMBER TO IT.
ASK USER TO GUESS A NUMBER.
IF USER GUESSED CORRECTLY THEN PRINT "YOU WIN" 
IF USER DIDN'T GUESSED CORRECTLY THEN:
    IF USER GUESSED LOWER THAN ACTUAL NUMBER THEN PRINT "TOO LOW"
    IF USER GUESSED HIGHER THAN ACTUAL NUMBER THEN PRINT "TOO HIGH"
    
    '''

#ans

# winning_num=5    
# guess_num=int(input(guess number between 1 to 10))
# if winning_num==guess_num :
#     print("you WIN!!!")
# if winning_num < guess_num :
#     print("too high")
# if winning_num>guess_num:
#     print('too low')



#or use nested if-else 
num=int(input("guess a number b/t 1 to 100: "))
winning_number = 26
print(num)
if num==winning_number:
    print("you win!!")
else:
    if num<winning_number:
        print("too low")
    else:
        print("too high")

# %%
#2

'''EXERCISE -WATCH COCO
ASK USER'S NAME AND AGE 
IF USER'S NAME START WITH ('a' OR 'A') AND AGE IS ABOVE 10 THEN 
PRINT "YOU CAN WATCH COCO"
ELSE PRINT "SORRY,YOU CANNOT WATCH COCO"
'''

name,age=input("enter your name and age here(space seperated ): ").split()
age=int(age)

if name.lower()[0] == "a" and age >10:
    print("you can watch coco")
else:
    print("sorry you can't watch coco")



# name= input('enter your name ')                          #bonus alternative way 
# age= int(input("your age "))
# if age>=10 and (name[0]=='a'or name[0]=="A"):               # WE HAVE USED   AND , OR    AT A ASME TIME.
#     print('you can watch coco movie  ')
# else:
#     print("sorry,you cannot watch coco ")

# %%
#3,4,5


'''exercise 3
sum of natural numbers 
ask a user for natural number(n)
print total from 1 to n'''

i=1
total=0
n=int(input("enter a natural number: "))
while i<=n:
    total+=i
    i+=1
print(total)





'''exercise 4 
problem 
ask user to input a number containig more than onr digit 
example-1256
calculate 1+2+5+6 and print 

algorithm- method to solve problem in human language 
ask input in string , i.e don't change string to int 
example-"1256"
pick string character one by one and change to int 
int(example[0])+int(example[1])+.........go upto len(example)'''

num=input("enter a integer: ")
total=0
i=0
while i<len(num):
    total+=int(num[i])
    i+=1
print(total)


#or explained code exercise 4
# num=input('enter a number containing more than one digit: ')

# n=len(num)
# i=0
# total=0
# while i<n:
#     total= total+int(num[i])
#     i=i+1
# print(total)



'''exercise 5 
ask a user for name 
example- Harshit Vashisth
print count of each words each
#output :
    H - 1
    a - 2
    r - 1
    s - 3
    h - 3
    i - 2
    t - 2
      - 1
    V - 1
note - ek character ko do bar count 
nhi krna '''

# name=input("enter your name: ")
# j=0
# while j<len(name):
    
#     print(f"{name[j]} - {name.count(name[j])}")
#     j+=1


# every charatcter single time 
# name=input("enter your name: ")
# j=0
# temp_var=""

# while j<len(name):
#     if name[j] not in temp_var:
#         temp_var+=name[j]     
#         print(f"{name[j]} - {name.count(name[j])}")
#     j+=1

# %%
#6

#modify number guessing game 


# import random 
# win_num=random.randint(1,100)
# num=int(input('enter a number b\w 1 and 100: '))
# guess=0

# while True:
#     guess +=1
#     if num == win_num:
#         print(f'you win!!! in {guess} guess')
#         break
#     else:
#         if num<win_num:
#             print("too low")
#             num=int(input('enter a number b\w 1 and 100: '))
#         else:
#             print('too high')
#             num=int(input('enter a number b\w 1 and 100: '))



#or 

import random 

win_num=random.randint(1,100)
num=int(input('enter a number b\w 1 and 100: '))

game_over= False
guess =1
while not game_over:
    
    if num == win_num:
        print(f'you win!!! in {guess} guess')
        game_over =True
        
    else:
        if num<win_num:
            print("too low")
            guess +=1
            num=int(input('enter a number b\w 1 and 100: '))
        else:
            print('too high')
            guess +=1
            num=int(input('enter a number b\w 1 and 100: '))
