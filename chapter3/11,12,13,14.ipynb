# %%
#11


# break and continue 

# printing only 1 to 5 (from a loop from 1 to 11)
for i in range (1,11):
    if i==5: 
        break
    print(i)
    
    
print('this is a line \n')


#print 1 to 10 , but not 5
for i in range(1,11):
    if i==5:
        continue
    print(i)

# %%
#12

#DRY principal of coding 
# import random 

# win_num=random.randint(1,100)
# num=int(input('enter a number b\w 1 and 100: '))

# game_over= False
# guess =1
# while not game_over:
    
#     if num == win_num:
#         print(f'you win!!! in {guess} guess')
#         game_over =True
        
#     else:
#         if num<win_num:
#             print("too low")
#         else:
#             print('too high')
#         guess +=1
#         num=int(input('enter a number b\w 1 and 100: '))




#or 

import random 

win_num=random.randint(1,100)

guess =1
while True:
    num=int(input('enter a number b\w 1 and 100: '))
    if num == win_num:
        print(f'you win!!! in {guess} guess')
        # game_over =True
        break
        
    else:
        if num<win_num:
            print("too low")
        else:
            print('too high')

        guess +=1
        continue

# %%
#13

#step argument in range function 
for i in range(1,11):
    print(i)
print('this is a line ')


print('odd number')
for i in range(1,11,2):
    print(i)

print('even number')
for i in range(0,11,2):
    print(i)


print('line')
#10,9,8....
#printing numbers in revese order
for i in range(10,0,-1):
    print(i)
 
for i in range(-1,-11,-1):
    print(i)

# %%
#14

#for loop and string 

#srtings in python are iterable 
name="harshit"
for i in name:
    print(i)

for i in "yash":
    print(i)

#sum of 1256 -> 1+2+5+6
num=input('enter a number')
total=0
for i in num:
    total+=int(i)
print(total)
