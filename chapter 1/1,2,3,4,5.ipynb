# %%
# 1

#print function
print('hello world!!')
print("hello world")
print ("hello 'world' world")
print ('hello "world" world')
# we can use "double quotes" inside 'single quotes' or
# 'single quotes' inside "double quotes".
print("hello i'm mudit ")

# but we can't use - "double quotes" inside "double quotes" or vice-versa 
# print ('hello i'm mudit')  #will show syntax error 
# print("hello i"m  here") #will show syntax error 


print ("hello world")
print ('hello world')
# print ("enter your name ") print ("I'am yash")      #error:invalid syntax 
# print ('hello 'world' world')         #SyntaxErro:invalid syntax    #in output

# %%
# 2


#    escape sequence 
print ("hello \"world\" world ")
print ('i\' am yash')
# always use single quotes or double quotes with escape sequqnce.
print('line A')
print ('line B')
print("\n")
print("line A\nline B")
print("line a \nline b\n line c") #new line
print("name\tharshit")  #tab 

print ("this is \ backslash") 
# but     print("this is backslash\")       syntax error : end of line error 
print ("this is backslash \\")   #backslash escape sequence
print ('this is double backslash\\\\') 
print ("helll\bo")    # backspace 


#   comment 
# comment is used by user for users information not interpreted by phython (or not a part of code).
# shortcut to comment a line is ctrl +/

# %%
# 3



# escape squence as a normal text 
print ("line A \\n line B")
print ("line A \\t line B")
print ("this is double backslash \\\\") 
print ("this is 4 backslash \\\\\\\\")
print (" \\\" \\\' ") 

# raw string 
print(r"line a \n line b ")
print (r" \' ")

# how to print emoji 
print ("\U0001F602")    # U0001F602 emoji source code  # unicode.org 
# get emoji from Website for unicode :- https://unicode.org/emoji/charts/full...

# %%
# 4


# phython as calculator 
print(2+3)  #addition 
print (2-3) #substraction 
print(2+3*4) #multiplication
print(2/4) # float division 
print(4/2)
print(4//2) #integer division
print(2//4)
print(3%2) # modulo,it gives the remainder 
print(2**3) #exponent
print(2**0.5)   # to find out square root of 2
print(round(2**0.5, 4)) # round of decimal function 

#precedence rule 
print((2+3)*2)
# (2+3)=5  --> then 5*2 

print((2+3)*5/2%6)
#5*5/2%6-4
# 25/2%6
print(12.5%6) #modulo

print(2**3/2*6-4*(3-4/2))
print(2**3**2) #exponent
# 2**(3**2) -> 2**9
# print(2**9)

#example -> roundof using variables 
x = 12423
y= 5

print(round(x/13,y))

# %%
# 5 


# variables,rules,conventions   
number1=2     #we can store numbers,strings in variables 
print(number1)
number1='5'
print(number1)


name= 'harshit' #string ,number   #python is a dynamic language 
print(name)
name = 123
print(name)

number2= 2.0    #float type value
print(number2)


# 1number= 2      #rule one (it gives error) - never start with no. in variables.
_name= "harshit v"  #leter,_  #rule two (variables can start with letters and underscore)
name="harshit v"
print(_name)
print(name)
# u$sd=34 or $usd=34 #rule three (can't use special sign in variables) (error)
u1sd=34
print(u1sd)
# my name="yash"  # we can't use space in between of variable name 
print(name)

#conventions
user_one_name= 'rohit'  #snake case writting 
userOneName = 'rohit 2'  #camel case writting 
print(user_one_name)
print(userOneName)

# %%
# exercise 1 


#*********print these following lines ********
# this is \\ double bacslash 
#this is mountain /\/\/\/\ 
# he is     awesome (use escape sequence instead of manual spaces )
# \" \n \t \' (print this as an output)


print("this is \\\\ double backslash")
print ("this is mountain /\/\/\/\/\\")
print("he is \tawesome")
print (' \\\" \\n \\t \\\'')

# %%
# summary

# summary chapter one 

#print function 
print("hello world")
print('hello!!')
print("hello i'm yash")
print('hello "world" world')

#escape sequences 
print("hello i\'m yash ")
print("line a \n line b")
print("name\t yash")
print("heli\blo")
print(' this is backslah\\')

#escape sequence as a normal text 
print(" \\n \\t \\' ")
print("\\\' \\\" ")
# or use raw string 
print(r"line a \n line b")

#python as calculator 
print(2+3)
print(2-3)
print(2*3)
print(3/4)
print(4//2)
print(2**3)
print(433%2)

print(2**3**2)
print((2+3)*4/3)

#variable
name=12
name="yash"
name='mudit'
print(name)
#_name="yash" #name="yash",name1="yash",name_is="mudit" #no error
#1name , %name ,u$sd  #error

#convention for variable naming 
var_one="harshit" #snake case 
varOneName="yash" #camel case
