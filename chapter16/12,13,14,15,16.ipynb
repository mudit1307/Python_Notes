# %%
#12
# property , setter ,decorator


# will discuss three problems in existing 
# then we will solve them using getter , setter decorator

# %%
class Phone:
    def __init__(self,brand,model_name,price): 
        self.brand=brand
        self.model_name =model_name

        # to set price zero if negaive value is provided

        # if price>0:
        #     self._price=price
        # else: 
        #     self._price=0
        self._price=max(price,0)

        #self.complete_specification = f"{self.brand}  {self.model_name} and price is {self._price}"
    def complete_specification(self):
        return  f"{self.brand} {self.model_name} and price is {self._price}"

    def make_a_call(self,phone_number):
        print(f"calling {phone_number} ...")
    
    def full_name(self):
        return f"{self.brand} {self.model_name}" 
    
    def send_message(self):
        pass


phone1 = Phone('nokia','1100',-1000)
print(phone1.brand)
print(phone1.model_name)
phone1._price= 500
print(phone1._price)
print(phone1.complete_specification())
# Out:
# nokia
# 1100
# 500
# nokia 1100 and price is 500

# %%
class Phone:
    def __init__(self,brand,model_name,price): 
        self.brand=brand
        self.model_name =model_name

        # to set price zero if negaive value is provided

        # if price>0:
        #     self._price=price
        # else: 
        #     self._price=0
        self._price=max(price,0)

        #self.complete_specification = f"{self.brand}  {self.model_name} and price is {self._price}"
    
    #by using property decorator we can use comlete_specification function as a attribute

    @property
    def complete_specification(self):
        return  f"{self.brand} {self.model_name} and price is {self._price}"

    def make_a_call(self,phone_number):
        print(f"calling {phone_number} ...")
    
    def full_name(self):
        return f"{self.brand} {self.model_name}" 
    
    def send_message(self):
        pass


phone1 = Phone('nokia','1100',-1000)
print(phone1.brand)
print(phone1.model_name)
phone1._price= 500
print(phone1._price)
print(phone1.complete_specification)
# Out:
# nokia
# 1100
# 500
# nokia 1100 and price is 500

# %%
class Phone:
    def __init__(self,brand,model_name,price): 
        self.brand=brand
        self.model_name =model_name

        # to set price zero if negaive value is provided

        # if price>0:
        #     self._price=price
        # else: 
        #     self._price=0
        self._price=max(price,0)

        #self.complete_specification = f"{self.brand}  {self.model_name} and price is {self._price}"
    
    #by using property decorator we can use comlete_specification function as a attribute

    @property
    def complete_specification(self):
        return  f"{self.brand} {self.model_name} and price is {self._price}"

    def make_a_call(self,phone_number):
        print(f"calling {phone_number} ...")
    
    def full_name(self):
        return f"{self.brand} {self.model_name}" 
    
    def send_message(self):
        pass


phone1 = Phone('nokia','1100',-1000)
print(phone1.brand)
print(phone1.model_name)
#it has problem of setting negative price value
phone1._price= -500
print(phone1._price)
print(phone1.complete_specification)
# Out:
# nokia
# 1100
# -500
# nokia 1100 and price is -500

# %%
class Phone:
    def __init__(self,brand,model_name,price): 
        self.brand=brand
        self.model_name =model_name

        # to set price zero if negaive value is provided

        # if price>0:
        #     self._price=price
        # else: 
        #     self._price=0
        self._price=max(price,0)

        #self.complete_specification = f"{self.brand}  {self.model_name} and price is {self._price}"
    
    #by using property decorator we can use comlete_specification function as a attribute

    @property
    def complete_specification(self):
        return  f"{self.brand} {self.model_name} and price is {self._price}"
    
    #getter() , setter()
    @property
    def price(self):
        return self._price
    @price.setter
    def price(self,new_price):
        self._price=max(new_price,0)
        

    def make_a_call(self,phone_number):
        print(f"calling {phone_number} ...")
    
    def full_name(self):
        return f"{self.brand} {self.model_name}" 
    
    def send_message(self):
        pass


phone1 = Phone('nokia','1100',-1000)
print(phone1.brand)
print(phone1.model_name)
phone1.price= -500
print(phone1.price)
print(phone1.complete_specification)
# Out:
# nokia
# 1100
# 0
# nokia 1100 and price is 0

# %%
print("hello")
# Out:
# hello

# %%
#13

# INHERITANCE INTRO

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone: 
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."


phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
print(phone.full_name())
print(smartphone.full_name())
# Out:
# nokia 1100
# onePlus 5

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #first ways
        Phone.__init__(self,brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera



phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
print(phone.full_name())
print(smartphone.full_name())
print(smartphone.full_name() + f" and price is {smartphone._price}")
# Out:
# nokia 1100
# onePlus 5
# onePlus 5 and price is 30000

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera



phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
print(phone.full_name())
print(smartphone.full_name())
print(smartphone.full_name() + f" and price is {smartphone._price}")
# Out:
# nokia 1100
# onePlus 5
# onePlus 5 and price is 30000

# %%
#14 

# more about inheritance, multilevel inheritance, MRO  , method overriding ,etc.

# %%
#can we drive more than one class from base class? 
#multilevel inheritance
#method resolution order
# method overriding 
#isinstance(), issubclass()

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera



phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
print(phone.full_name())
print(smartphone.full_name())
print(smartphone.full_name() + f" and price is {smartphone._price}")
# Out:
# nokia 1100
# onePlus 5
# onePlus 5 and price is 30000

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera

class FlagshipPhone(Smartphone):
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera,front_camera):
        super().__init__(brand,model_name,price,ram,internal_memory,rear_camera)
        self.front_camera=front_camera


phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
oneplus= FlagshipPhone('onePlus','5',30000, "6 GB", "64 GB","20 MP","16 MP")
print(oneplus.full_name())
print(oneplus.full_name() + f" and price is {oneplus._price}")
# Out:
# onePlus 5
# onePlus 5 and price is 30000

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera

class FlagshipPhone(Smartphone):
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera,front_camera):
        super().__init__(brand,model_name,price,ram,internal_memory,rear_camera)
        self.front_camera=front_camera


# phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
oneplus= FlagshipPhone('onePlus','6',30000, "6 GB", "64 GB","20 MP","16 MP")
print(smartphone.full_name())
print(oneplus.full_name())

#method resolution operator
print(help(smartphone))
print(help(oneplus))
# Out:
# onePlus 5
# onePlus 6
# Help on Smartphone in module __main__ object:
#
# class Smartphone(Phone)
#  |  Smartphone(brand, model_name, price, ram, internal_memory, rear_camera)
#  |
#  |  Method resolution order:
#  |      Smartphone
#  |      Phone
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, brand, model_name, price, ram, internal_memory, rear_camera)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Phone:
#  |
#  |  full_name(self)
#  |
#  |  make_a_call(self, number)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Phone:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# None
# Help on FlagshipPhone in module __main__ object:
# ...

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera
        
    #method overridding
    def full_name(self):
        return f"{self.brand} {self.model_name} and price is {self._price}"

class FlagshipPhone(Smartphone):
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera,front_camera):
        super().__init__(brand,model_name,price,ram,internal_memory,rear_camera)
        self.front_camera=front_camera


phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
oneplus= FlagshipPhone('onePlus','6',30000, "6 GB", "64 GB","20 MP","16 MP")
print(smartphone.full_name())
print(oneplus.full_name())
# Out:
# onePlus 5 and price is 30000
# onePlus 6 and price is 30000

# %%
class Phone: #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera
        
    #method overridding
    def full_name(self):
        return f"{self.brand} {self.model_name} and price is {self._price}"

class FlagshipPhone(Smartphone):
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera,front_camera):
        super().__init__(brand,model_name,price,ram,internal_memory,rear_camera)
        self.front_camera=front_camera
    
    #method overridding
    def full_name(self):
        return f"{self.brand} {self.model_name} and price is {self._price} and front_camera is {self.front_camera}"


phone = Phone('nokia','1100',1000)
smartphone= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
oneplus= FlagshipPhone('onePlus','6',30000, "6 GB", "64 GB","20 MP","16 MP")
print(smartphone.full_name())
print(oneplus.full_name())
# Out:
# onePlus 5 and price is 30000
# onePlus 6 and price is 30000 and front_camera is 16 MP

# %%
class Phone:  #base class/ parent class
    def __init__(self,brand,model_name,price):
        self.brand=brand
        self.model_name =model_name
        self._price=max(price,0)
    
    def full_name(self):
        return f"{self.brand} {self.model_name}"
    
    def make_a_call(self,number):
        return f"calling {number}...."
    

class Smartphone(Phone): #derived class / child class
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera):

        #second ways - using  super

        super().__init__(brand,model_name,price)

        self.ram= ram
        self.internal_memory=internal_memory
        self.rear_camera=rear_camera
        
    #method overridding
    def full_name(self):
        return f"{self.brand} {self.model_name} and price is {self._price}"

class FlagshipPhone(Smartphone):
    def __init__(self,brand,model_name,price,ram,internal_memory,rear_camera,front_camera):
        super().__init__(brand,model_name,price,ram,internal_memory,rear_camera)
        self.front_camera=front_camera
    
    #method overridding
    def full_name(self):
        return f"{self.brand} {self.model_name} and price is {self._price} and front_camera is {self.front_camera}"


phone = Phone('nokia','1100',1000)
oneplus5= Smartphone('onePlus','5',30000, "6 GB", "64 GB","20 MP")
oneplus5t= FlagshipPhone('onePlus','5t',30000, "6 GB", "64 GB","20 MP","16 MP")
print(oneplus5.full_name())
print(oneplus5t.full_name())

print()

# isinstance() -  isinstance(object,class) - is used to check that the particular object is a intance of given class or not.

print(isinstance(oneplus5,Phone))
print(isinstance(oneplus5,Smartphone))
print(isinstance(oneplus5,FlagshipPhone))

print()

print(isinstance(oneplus5t,FlagshipPhone))
print(isinstance(oneplus5,Smartphone))

print()

#issubclass - to check is first class is a subclass of  second class 
# issubclass(first_class,second_class)

print(issubclass(FlagshipPhone,Smartphone))
print(issubclass(FlagshipPhone,Phone))
print(issubclass(Smartphone,FlagshipPhone))
print(issubclass(Phone,FlagshipPhone))
# Out:
# onePlus 5 and price is 30000
# onePlus 5t and price is 30000 and front_camera is 16 MP
#
# True
# True
# False
#
# True
# True
#
# True
# True
# False
# False

# %%
#15
# multiple inheritance
# usually avoid this type of inheritance in program

# %%
class A:
    def class_a_method(self):
        return "I\'m  just a class A method"
    
    def hello(self):
        return "hello from class A"
 
instance_a=A()
print(instance_a.class_a_method())
# Out:
# I'm  just a class A method

# %%
class A:
    def class_a_method(self):
        return "I\'m  just a class A method"
    
    def hello(self):
        return "hello from class A"

class B:
    def class_b_method(self):
        return "I\'m  just a class B method"
    
    def hello(self):
        return "hello from class B"

class C(A,B):
    pass

instance_c =C()

print(instance_c.class_a_method())
print(instance_c.class_b_method())

# print(help(C))
print(instance_c.hello())  #it call hello() from A class due to order of multiple inheritance {(A,B)}
# Out:
# I'm  just a class A method
# I'm  just a class B method
# hello from class A

# %%
class A:
    def class_a_method(self):
        return "I\'m  just a class A method"
    
    def hello(self):
        return "hello from class A"

class B:
    def class_b_method(self):
        return "I\'m  just a class B method"
    
    def hello(self):
        return "hello from class B"

class C(A,B):
    pass

instance_c =C()

print(instance_c.class_a_method())
print(instance_c.class_b_method())


print(instance_c.hello())  #it call hello() from A class due to order of multiple inheritance {(A,B)}

# print(help(C))

#or
#can also use mro() to check order - and it return a list 

print(C.mro())

#return tuple
print(C.__mro__)
# Out:
# I'm  just a class A method
# I'm  just a class B method
# hello from class A
# [<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>]
# (<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>)

# %%
#16 
# magic/dunder methods, operator oveloading, polymorphism.
