# %%
#6

#default parameters 
def user_info(first_name,last_name,age=None):
    print(f"your first name is {first_name}")
    print(f"your last name is {last_name}")
    print(f"your age is {age}")

user_info('harshit','vashistha',24)

user_info('harshit')
#user_info('harshit',24)    #ERROR

def user_info1(first_name,last_name,age=None):
    print('your first name is {}'.format(first_name))
    print('your last name is {}'.format(last_name))
    print('your age is {}'.format(age))
    
user_info1('harshit','vashistha',24)


def user_info2(first_name,last_name='unknown',age=None):
    print('your first name is {}'.format(first_name))
    print('your last name is {}'.format(last_name))
    print('your age is {}'.format(age))

user_info2('harshit')


#syntax error - when non-default argument follows default argument.
#def user_info(first_name,last_name='unknown',age):
#here age as a non-default argument folows defalut argument last_name.   #syntax error

# %%
#7

#variable scope 

#scope 
'''
def func():
    x=7           #local variable-declare inside the function 
    return x

def func2():
    print (x)     #error
    
funct2()

print(x)          #error


#NAME error: name 'x'is not defined 
    
    '''

def func():
    x=7
    return x
    
print(func())

y=5              #global variable 
def fun():
    y=7          #local variable 
    return y

print(fun())
print(y)

#the value of "global variable" is not affected when same
#variable declared aS a local variable in a function.(as in the above case)

#to use the same global variable in the function 
x=8
def fu():
    global x
    x=12
    return x

print(x)
print(fu())
print(x)
