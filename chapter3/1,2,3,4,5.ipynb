# %%
#1

# chapter 3

# if statement 
age=int(input('enter your age '))
if age>=14:                            #if statement
    print('your are above 14')         #if block 
    print('line a')




# pass statment      #used when nothing to write in if block ( or when if block ..  empty )

# age=int(input('enter your age '))               
# if age>=14:           if statement
# -----                   if block empty    #error 

age=14
if age>14: 
    pass       # no error       

age=int(input('enter your age '))
if age>=14: 
    pass      #no error

# %%
#2 


#if-else statement 

age= int(input('enter your age '))
if age>=14    : 
    print('you are above 14 ')
else:
    print('sorry you can\'t play')

# %%
#3

# nested if-else 


winning_num=27
user_input=int(input('guess a number b/w 0 to 50\n '))
if user_input==winning_num:
    print('you win!!')
else:                              #nested if else 
    if user_input<winning_num:                                 
        print('too low')
    else:                          #nested if else here too
            print('too high')

# %%
#4 

# and,or operator 
name='abc'
age=19

if name=='abc'  and age ==19 :         #1     and, both condition must be true 
    print('condition true ')
else:
    print('condition false ')


if name=='abc'  and age ==14 :         #2    and,  both condition must be true 
    print('condition true ')
else:
    print('condition false ')
    
    
if name=='abcddd'  and age ==19 :         #3   and,  both condition must be true 
    print('condition true ')
else:
    print('condition false ')



if name=='abc'  or age ==19 :         #1    or, atleast one must be true 
    print('condition true ')
else:
    print('condition false ')


if name=='abcddd'  or age ==19 :         #2    or, atleast one must be true 
    print('condition true ')
else:
    print('condition false ')


if name=='abcddd'  or age ==56 :         #3    or, atleast one must be true 
    print('condition true ')
else:
    print('condition false ')

# %%
#5 

# if-elif-else statement 


age=int(input("please input your age : "))

if age==0 or age<0:
    print("pls,enter a valid age")
elif 0<age<=3:
    print('ticket price : Freee')
elif 3<age<=10:
    print('ticket price : 150 ')
elif 10<age<=60: 
    print('ticket price : 250')
else:
    print('ticket price : 200 ')




#example (showing diff. in elif ,if (or use of elif))

'''when we use if statement then it will check for every statement...'''
age = 3
 
if 0<age<=3:
     print("ticket is free")     #input-> 3
if 3<=age<=11:
    print("ticket price 100")

'''when we use elif statement then it terminates the sequence of statment after any one statement goes true..'''
age = 3

if 0<age<=3:
     print("ticket is free")       #input-> 3
elif 3<=age<=11:
    print("ticket price 100")
